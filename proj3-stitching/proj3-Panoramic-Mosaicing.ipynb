# %% [markdown]
# # Project 3: Panoramic Mosaicing
#
# ### What to Submit
# Submit this iPython Notebook--containing all your code for the programming exercises below--on [learning suite](https://learningsuite.byu.edu/).
#
# Your notebook file should produce the relevant plots and also provide a short write-up with answers to the questions below.
#
# Please also fill in here the time that each part took you:
# * 1. Part A: <span style="color:red;">20 min</span>
# * 2. Part B: <span style="color:red;">FILL IN TIME</span>
# * 3. Part C: <span style="color:red;">FILL IN TIME</span>
# * 4. Part D: <span style="color:red;">FILL IN TIME</span>
# * 5. Write-up: <span style="color:red;">FILL IN TIME</span>
#
# ### Programming Exercise
#
# For this assignment, you will be writing a program that creates a panoramic mosaic from 2 or more images.  In general this technique should be applicable to any number of photographs.  The approach described below will work well for collective fields of up to 90 or even 120&deg;, but won't produce ideal results for large fields of view approaching or surpassing 180&deg;.  For large fields of view cylindrical or spherical projection is required.
#
# When we construct a panorama, we assume that all of the photographs were taken from the exact same location and that the images are related by pure rotation (no translation of the camera).  The easiest way to create the panorama is to project all of the photos onto a plane.  One photo must be selected (either manually or by your program) to be the base photo.  The other photos are aligned to this base photo by identifying a homography (a planar warp specified by 4 pairs of source/destination points) relating each pair.  Each of the other images is appropriately warped and composited onto the plane (the base image doesn’t need to be warped).
#
# In describing what you need to do, there will be a running example using the three photos below:
#
#
# <div style="width:100%;text-align:center;"><img src="Images/example1.png" width=100%></div>

# %% [markdown]
# ### Part A: Find Interest Points/Descriptors in each Input Image
# We will be using OpenCV for this project, which you should already have installed.  However, you may need to install the contrib version--which comes seperate due to the SIFT algorithm being patented--by running the command:`pip install opencv-contrib-python`.  A good tutorial on how to use SIFT features in OpenCV is found [here](https://docs.opencv.org/trunk/da/df5/tutorial_py_sift_intro.html).  The first step to registering or aligning two images is to identify locations in each image that are distinctive or stand out.  The `sift.detectAndCompute()` routine produces both these interest points and their corresponding SIFT descriptors.  The first step of producing a panorama is to load all of the relevant images and find the interest points and their descriptors.
#
# See the red circles on each image below indicating the sift keypoints that were found (note that we downsampled the images to 600 x 600 pixels before extracting SIFT).  We scaled the circles according to the scale at which each keypoint was detected at.
#
# <div style="width:100%;text-align:center;"><img src="Images/example2.png" width=100%></div>

# %% [markdown]
# ### Part B: Matching Features
#
# Next, given the features present in each image, you need to match the features so as to determine corresponding points between adjacent/overlapping images.  [This page](https://docs.opencv.org/trunk/dc/dc3/tutorial_py_matcher.html) provides details to do feature matching using `cv2.BFMatcher()`, analogous to the approach proposed by David Lowe in his original implementation.  Be aware that the resulting match is one directional.  You want to find putative pairs--pairs of points which are each other’s best match (e.g. there might be 3 points in image I1 for which a point q in image I2 are the best match, only one of these could be the best matching point p in I1 for that point q in I2).  In this part you need to compute the set of putative matches between each pair of images.
#
# Look at the pairs of images and the lines showing the estimated matches (putative matches are green lines, one way matches are cyan or blue).
#
# <div style="width:100%;text-align:center;"><img src="Images/example3.png" width=100%></div>

# %% [markdown]
# ### Part C: Estimating Pairwise Homographies using RANSAC
#
# Use the RANSAC algorithm ([Szeliski](http://szeliski.org/Book/), Ch 6.1.4), estimate the homography between each pair of images.  You will need to decide whether you’re going to manually specify the base image or determine in programmatically.  Along with identifying the base image, you need to figure out the order in which you will composite the other images to the base.
#
# You will need 4 pairs of points to estimate a homography.  Begin by randomly sampling sets of 4 pairs and estimating the corresponding homography for each set.  Instead of the two warping equations that we used earlier in the semester, it is recommended that you use a 3x3 homography (8 unknowns).  You are trying to estimate the homography
#
# $$
# \begin{bmatrix}a & b & c\\d & e & f\\g & h & 1\end{bmatrix}
# $$
#
# such that a point $(x_s,y_s)$ in the source image is tranformed to a point $(x_t,y_t)$ in the target image as follows
#
# $$
# \begin{bmatrix}x_t\\y_t\\1\end{bmatrix} = \begin{bmatrix}a & b & c\\d & e & f\\g & h & 1\end{bmatrix}\begin{bmatrix}x_s\\y_s\\1\end{bmatrix}
# $$
#
# Each pair of points will produce three linear equations in (a subset of) the 8 unknowns.  For example, $x_t = x_sa + y_sb + c$.  Four pairs of points (assuming no degeneracies) are sufficient to estimate the homography.  A more robust solution relying on more than four pairs can be obtained using least squares on the overconstrained linear system (solving $Ax = b$, where $x$ is a column vector with the 8 unknowns and you populate rows of $A$ and an entry of $b$ with the linear equations just described).  Note that this solution will **not** always be better.
#
# Because of the homogeneous coordinates, the three equations can be reduced to two equations as follows:
#
# $$
# x_t = \frac{ax_s+by_s+c}{gx_s+hy_s+1}, \hspace{5mm}
# y_t = \frac{dx_s+ey_s+f}{gx_s+hy_s+1}
# $$
#
# For more details, see the [image alignment and stitching slides](https://faculty.cs.byu.edu/~farrell/courses/CS450/slides/alignment_stitching.pdf#page=18).
#
# Below you will find a visualization of the RANSAC estimated homographies.  Images 1, 2, and 3 have dots that are red, green and blue respectively (sorry the dots are a little small), representing the putative pairs.  You can see where the homographies line up very well and in a few places (the middle vertically) they line up slightly less well.
#
# <div style="width:100%;text-align:center;"><img src="Images/example4.png" width=100%></div>

# %% [markdown]
# ### Part D: Creating the Mosaic
#
# Begin with the base image and warp the remaining images (using the estimated homographies) to composite them onto the base image.
#
# For the ongoing campus example, here are the resulting warped images composited.
#
# <div style="width:100%;text-align:center;"><img src="Images/example5.png" width=75%></div>
#
# And, then with a very simple (but not ideal) compositing operation.
#
# <div style="width:100%;text-align:center;"><img src="Images/example6.png" width=75%></div>

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Part A: Find Interest Points/Descriptors

# %%
# Place Code Here
# Show an example output here

def getSIFT(img, draw=False):
    scale = 20
    width = int(img.shape[1] * scale / 100)
    height = int(img.shape[0] * scale / 100)

    img = cv2.resize(img, (width,height))
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    sift = cv2.SIFT_create()
    kp, des = sift.detectAndCompute(gray, None)

    if draw:
        plt.imshow(cv2.drawKeypoints(gray, kp, img, flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS), cmap='gray');plt.show()

    return kp, des


img = cv2.imread("Images/campus1.jpg")
img = img[:,:,::-1]
kp, des = getSIFT(img, True)

img = cv2.imread("Images/campus3.jpg")
img = img[:,:,::-1]
getSIFT(img, True)

img = cv2.imread("Images/campus2.jpg")
img = img[:,:,::-1]
getSIFT(img, True)
# Out:
# ((< cv2.KeyPoint 0x7f8aef1f29f0>,
#   < cv2.KeyPoint 0x7f8a38aed060>,
#   < cv2.KeyPoint 0x7f8aee940ab0>,
#   < cv2.KeyPoint 0x7f8a887d8030>,
#   < cv2.KeyPoint 0x7f8a39185990>,
#   < cv2.KeyPoint 0x7f8a39185930>,
#   < cv2.KeyPoint 0x7f8a39185b40>,
#   < cv2.KeyPoint 0x7f8a391859f0>,
#   < cv2.KeyPoint 0x7f8a39185960>,
#   < cv2.KeyPoint 0x7f8a391859c0>,
#   < cv2.KeyPoint 0x7f8a39185cc0>,
#   < cv2.KeyPoint 0x7f8a39185ed0>,
#   < cv2.KeyPoint 0x7f8a39185c00>,
#   < cv2.KeyPoint 0x7f8a39185d20>,
#   < cv2.KeyPoint 0x7f8a39185540>,
#   < cv2.KeyPoint 0x7f8a391a6210>,
#   < cv2.KeyPoint 0x7f8a391a61e0>,
#   < cv2.KeyPoint 0x7f8a391a6120>,
#   < cv2.KeyPoint 0x7f8a391a6060>,
#   < cv2.KeyPoint 0x7f8a391a62d0>,
#   < cv2.KeyPoint 0x7f8a391a6330>,
#   < cv2.KeyPoint 0x7f8a391a6360>,
#   < cv2.KeyPoint 0x7f8a391a6390>,
#   < cv2.KeyPoint 0x7f8a391a63c0>,
#   < cv2.KeyPoint 0x7f8a391a63f0>,
#   < cv2.KeyPoint 0x7f8a391a6450>,
#   < cv2.KeyPoint 0x7f8a391a64b0>,
#   < cv2.KeyPoint 0x7f8a391a6510>,
#   < cv2.KeyPoint 0x7f8a391a6570>,
#   < cv2.KeyPoint 0x7f8a391a65a0>,
#   < cv2.KeyPoint 0x7f8a391a65d0>,
#   < cv2.KeyPoint 0x7f8a391a6600>,
#   < cv2.KeyPoint 0x7f8a391a6300>,
#   < cv2.KeyPoint 0x7f8a391a62a0>,
#   < cv2.KeyPoint 0x7f8a391a6690>,
#   < cv2.KeyPoint 0x7f8a391a6750>,
#   < cv2.KeyPoint 0x7f8a391a6780>,
#   < cv2.KeyPoint 0x7f8a391a67b0>,
#   < cv2.KeyPoint 0x7f8a391a67e0>,
#   < cv2.KeyPoint 0x7f8a391a6480>,
#   < cv2.KeyPoint 0x7f8a391a6870>,
#   < cv2.KeyPoint 0x7f8a391a64e0>,
#   < cv2.KeyPoint 0x7f8a391a68a0>,
#   < cv2.KeyPoint 0x7f8a391a6540>,
#   < cv2.KeyPoint 0x7f8a391a6900>,
#   < cv2.KeyPoint 0x7f8a391a6960>,
#   < cv2.KeyPoint 0x7f8a391a6270>,
#   < cv2.KeyPoint 0x7f8a391a6990>,
#   < cv2.KeyPoint 0x7f8a391a6720>,
#   < cv2.KeyPoint 0x7f8a391a66c0>,
#   < cv2.KeyPoint 0x7f8a391a6a20>,
#   < cv2.KeyPoint 0x7f8a391a6a50>,
#   < cv2.KeyPoint 0x7f8a391a6a80>,
#   < cv2.KeyPoint 0x7f8a391a6ae0>,
#   < cv2.KeyPoint 0x7f8a391a6b10>,
#   < cv2.KeyPoint 0x7f8a391a6b70>,
#   < cv2.KeyPoint 0x7f8a391a6840>,
#   < cv2.KeyPoint 0x7f8a391a6c00>,
#   < cv2.KeyPoint 0x7f8a391a6c30>,
#   < cv2.KeyPoint 0x7f8a391a6c90>,
#   < cv2.KeyPoint 0x7f8a391a69f0>,
#   < cv2.KeyPoint 0x7f8a391a66f0>,
#   < cv2.KeyPoint 0x7f8a391a68d0>,
#   < cv2.KeyPoint 0x7f8a391a6cc0>,
#   < cv2.KeyPoint 0x7f8a391a6d20>,
#   < cv2.KeyPoint 0x7f8a391a6d50>,
#   < cv2.KeyPoint 0x7f8a391a6d80>,
#   < cv2.KeyPoint 0x7f8a391a6db0>,
#   < cv2.KeyPoint 0x7f8a391a6de0>,
#   < cv2.KeyPoint 0x7f8a391a6e10>,
#   < cv2.KeyPoint 0x7f8a391a6e40>,
#   < cv2.KeyPoint 0x7f8a391a6e70>,
#   < cv2.KeyPoint 0x7f8a391a6bd0>,
#   < cv2.KeyPoint 0x7f8a391a6ea0>,
#   < cv2.KeyPoint 0x7f8a391a6ed0>,
#   < cv2.KeyPoint 0x7f8a391a6c60>,
#   < cv2.KeyPoint 0x7f8a391a69c0>,
#   < cv2.KeyPoint 0x7f8a391a6f60>,
#   < cv2.KeyPoint 0x7f8a391a6f90>,
#   < cv2.KeyPoint 0x7f8a391a6fc0>,
#   < cv2.KeyPoint 0x7f8a391a6cf0>,
#   < cv2.KeyPoint 0x7f8a391a6f30>,
#   < cv2.KeyPoint 0x7f8a391a6660>,
#   < cv2.KeyPoint 0x7f8a391a6930>,
#   < cv2.KeyPoint 0x7f8a391a6b40>,
#   < cv2.KeyPoint 0x7f8a391a6f00>,
#   < cv2.KeyPoint 0x7f8a391a60c0>,
#   < cv2.KeyPoint 0x7f8a391a6ab0>,
#   < cv2.KeyPoint 0x7f8a391a6ba0>,
#   < cv2.KeyPoint 0x7f8a391a6420>,
#   < cv2.KeyPoint 0x7f8a391a6630>,
#   < cv2.KeyPoint 0x7f8a391a6810>,
#   < cv2.KeyPoint 0x7f8a88bd98a0>,
#   < cv2.KeyPoint 0x7f8a88bd9870>,
#   < cv2.KeyPoint 0x7f8a88bd9840>,
#   < cv2.KeyPoint 0x7f8a88bd9cc0>,
#   < cv2.KeyPoint 0x7f8a88bd9f60>,
#   < cv2.KeyPoint 0x7f8a88bd9d50>,
#   < cv2.KeyPoint 0x7f8a88bd98d0>,
#   < cv2.KeyPoint 0x7f8a88bd5150>,
#   < cv2.KeyPoint 0x7f8a88b34360>,
#   < cv2.KeyPoint 0x7f8a88b340f0>,
#   < cv2.KeyPoint 0x7f8a88b34630>,
#   < cv2.KeyPoint 0x7f8a88b345d0>,
#   < cv2.KeyPoint 0x7f8a88b34690>,
#   < cv2.KeyPoint 0x7f8a88b349f0>,
#   < cv2.KeyPoint 0x7f8a88b347e0>,
#   < cv2.KeyPoint 0x7f8a88b34780>,
#   < cv2.KeyPoint 0x7f8a88b34480>,
#   < cv2.KeyPoint 0x7f8a88b34870>,
#   < cv2.KeyPoint 0x7f8a88b34840>,
#   < cv2.KeyPoint 0x7f8a88b34510>,
#   < cv2.KeyPoint 0x7f8a88b34570>,
#   < cv2.KeyPoint 0x7f8a88b34660>,
#   < cv2.KeyPoint 0x7f8a88b34270>,
#   < cv2.KeyPoint 0x7f8a88b34060>,
#   < cv2.KeyPoint 0x7f8a88b34420>,
#   < cv2.KeyPoint 0x7f8a88b34450>,
#   < cv2.KeyPoint 0x7f8a88b34720>,
#   < cv2.KeyPoint 0x7f8a88b348d0>,
#   < cv2.KeyPoint 0x7f8a88b34900>,
#   < cv2.KeyPoint 0x7f8a88b348a0>,
#   < cv2.KeyPoint 0x7f8a88b34300>,
#   < cv2.KeyPoint 0x7f8a88b34990>,
#   < cv2.KeyPoint 0x7f8a88b34930>,
#   < cv2.KeyPoint 0x7f8a88b341b0>,
#   < cv2.KeyPoint 0x7f8a88b34210>,
#   < cv2.KeyPoint 0x7f8a88b34960>,
#   < cv2.KeyPoint 0x7f8a88b34810>,
#   < cv2.KeyPoint 0x7f8a88b34ab0>,
#   < cv2.KeyPoint 0x7f8a88b343c0>,
#   < cv2.KeyPoint 0x7f8a88b341e0>,
#   < cv2.KeyPoint 0x7f8a88b34390>,
#   < cv2.KeyPoint 0x7f8a88b34b10>,
#   < cv2.KeyPoint 0x7f8a88b34b40>,
#   < cv2.KeyPoint 0x7f8a88b34a80>,
#   < cv2.KeyPoint 0x7f8a88b34a50>,
#   < cv2.KeyPoint 0x7f8a88b34c30>,
#   < cv2.KeyPoint 0x7f8a88b34a20>,
#   < cv2.KeyPoint 0x7f8a88b34e40>,
#   < cv2.KeyPoint 0x7f8a88b344e0>,
#   < cv2.KeyPoint 0x7f8a88b343f0>,
#   < cv2.KeyPoint 0x7f8a88b349c0>,
#   < cv2.KeyPoint 0x7f8a88b34de0>,
#   < cv2.KeyPoint 0x7f8a88b34cf0>,
#   < cv2.KeyPoint 0x7f8a88b34180>,
#   < cv2.KeyPoint 0x7f8a88b34bd0>,
#   < cv2.KeyPoint 0x7f8a88b342a0>,
#   < cv2.KeyPoint 0x7f8a88b34c00>,
#   < cv2.KeyPoint 0x7f8a88b34f00>,
#   < cv2.KeyPoint 0x7f8a88b34ed0>,
#   < cv2.KeyPoint 0x7f8a88b34cc0>,
#   < cv2.KeyPoint 0x7f8a88b34d80>,
#   < cv2.KeyPoint 0x7f8a88b34d20>,
#   < cv2.KeyPoint 0x7f8a88b34ba0>,
#   < cv2.KeyPoint 0x7f8a88b34fc0>,
#   < cv2.KeyPoint 0x7f8a88b34f30>,
#   < cv2.KeyPoint 0x7f8a88b34600>,
#   < cv2.KeyPoint 0x7f8a88b34d50>,
#   < cv2.KeyPoint 0x7f8a88b34330>,
#   < cv2.KeyPoint 0x7f8a88b34750>,
#   < cv2.KeyPoint 0x7f8a88b340c0>,
#   < cv2.KeyPoint 0x7f8a88b34c90>,
#   < cv2.KeyPoint 0x7f8a88b34ea0>,
#   < cv2.KeyPoint 0x7f8a88b344b0>,
#   < cv2.KeyPoint 0x7f8a88b34e70>,
#   < cv2.KeyPoint 0x7f8a88b34ae0>,
#   < cv2.KeyPoint 0x7f8a88b34c60>,
#   < cv2.KeyPoint 0x7f8a88b34b70>,
#   < cv2.KeyPoint 0x7f8a88b347b0>,
#   < cv2.KeyPoint 0x7f8a88b34e10>,
#   < cv2.KeyPoint 0x7f8a88b34f90>,
#   < cv2.KeyPoint 0x7f8a88b342d0>,
#   < cv2.KeyPoint 0x7f8a88b34090>,
#   < cv2.KeyPoint 0x7f8a88b34540>,
#   < cv2.KeyPoint 0x7f8a88b345a0>,
#   < cv2.KeyPoint 0x7f8a88b34f60>,
#   < cv2.KeyPoint 0x7f8a88b34150>,
#   < cv2.KeyPoint 0x7f8a88b34db0>,
#   < cv2.KeyPoint 0x7f8a88b34240>,
#   < cv2.KeyPoint 0x7f8a88b34120>,
#   < cv2.KeyPoint 0x7f8a88b346c0>,
#   < cv2.KeyPoint 0x7f8a88bd3450>,
#   < cv2.KeyPoint 0x7f8a88bd33f0>,
#   < cv2.KeyPoint 0x7f8a88bd39f0>,
#   < cv2.KeyPoint 0x7f8a88bd3b10>,
#   < cv2.KeyPoint 0x7f8a88bd3a50>,
#   < cv2.KeyPoint 0x7f8a88bd3930>,
#   < cv2.KeyPoint 0x7f8a88bd3b40>,
#   < cv2.KeyPoint 0x7f8a88bd3900>,
#   < cv2.KeyPoint 0x7f8a88bd3840>,
#   < cv2.KeyPoint 0x7f8a88bd37e0>,
#   < cv2.KeyPoint 0x7f8a88bd3780>,
#   < cv2.KeyPoint 0x7f8a88bd3720>,
#   < cv2.KeyPoint 0x7f8a88bd36f0>,
#   < cv2.KeyPoint 0x7f8a88bd3630>,
#   < cv2.KeyPoint 0x7f8a88bd35d0>,
#   < cv2.KeyPoint 0x7f8a88bd3570>,
#   < cv2.KeyPoint 0x7f8a88bd34e0>,
#   < cv2.KeyPoint 0x7f8a88bd3120>,
#   < cv2.KeyPoint 0x7f8a88bd3180>,
#   < cv2.KeyPoint 0x7f8a88bd32a0>,
#   < cv2.KeyPoint 0x7f8a88bd3390>,
#   < cv2.KeyPoint 0x7f8a88bd3bd0>,
#   < cv2.KeyPoint 0x7f8a88bd3990>,
#   < cv2.KeyPoint 0x7f8a88bd3ba0>,
#   < cv2.KeyPoint 0x7f8a88bd3c00>,
#   < cv2.KeyPoint 0x7f8a88bd3c30>,
#   < cv2.KeyPoint 0x7f8a88bd3c60>,
#   < cv2.KeyPoint 0x7f8a88bd3c90>,
#   < cv2.KeyPoint 0x7f8a88bd3cc0>,
#   < cv2.KeyPoint 0x7f8a88bd3cf0>,
#   < cv2.KeyPoint 0x7f8a88bd3d20>,
#   < cv2.KeyPoint 0x7f8a88bd3d50>,
#   < cv2.KeyPoint 0x7f8a88bd3d80>,
#   < cv2.KeyPoint 0x7f8a88bd3510>,
#   < cv2.KeyPoint 0x7f8a88bd3db0>,
#   < cv2.KeyPoint 0x7f8a88bd3de0>,
#   < cv2.KeyPoint 0x7f8a88bd3e10>,
#   < cv2.KeyPoint 0x7f8a88bd3e40>,
#   < cv2.KeyPoint 0x7f8a88bd3e70>,
#   < cv2.KeyPoint 0x7f8a88bd3ea0>,
#   < cv2.KeyPoint 0x7f8a88bd3ed0>,
#   < cv2.KeyPoint 0x7f8a88bd3f00>,
#   < cv2.KeyPoint 0x7f8a88bd3f30>,
#   < cv2.KeyPoint 0x7f8a88bd3f60>,
#   < cv2.KeyPoint 0x7f8a88bd3f90>,
#   < cv2.KeyPoint 0x7f8a88bd3fc0>,
#   < cv2.KeyPoint 0x7f8a38a5d060>,
#   < cv2.KeyPoint 0x7f8a38a5d0c0>,
#   < cv2.KeyPoint 0x7f8a38a5d0f0>,
#   < cv2.KeyPoint 0x7f8a38a5d150>,
#   < cv2.KeyPoint 0x7f8a38a5d180>,
#   < cv2.KeyPoint 0x7f8a38a5d1b0>,
#   < cv2.KeyPoint 0x7f8a38a5d1e0>,
#   < cv2.KeyPoint 0x7f8a38a5d210>,
#   < cv2.KeyPoint 0x7f8a38a5d240>,
#   < cv2.KeyPoint 0x7f8a38a5d270>,
#   < cv2.KeyPoint 0x7f8a38a5d2a0>,
#   < cv2.KeyPoint 0x7f8a38a5d2d0>,
#   < cv2.KeyPoint 0x7f8a38a5d300>,
#   < cv2.KeyPoint 0x7f8a38a5d330>,
#   < cv2.KeyPoint 0x7f8a38a5d030>,
#   < cv2.KeyPoint 0x7f8a38a5d360>,
#   < cv2.KeyPoint 0x7f8a38a5d390>,
#   < cv2.KeyPoint 0x7f8a38a5d3c0>,
#   < cv2.KeyPoint 0x7f8a38a5d3f0>,
#   < cv2.KeyPoint 0x7f8a38a5d120>,
#   < cv2.KeyPoint 0x7f8a38a5d420>,
#   < cv2.KeyPoint 0x7f8a38a5d450>,
#   < cv2.KeyPoint 0x7f8a38a5d480>,
#   < cv2.KeyPoint 0x7f8a38a5d510>,
#   < cv2.KeyPoint 0x7f8a38a5d5a0>,
#   < cv2.KeyPoint 0x7f8a38a5d6c0>,
#   < cv2.KeyPoint 0x7f8a38a5d6f0>,
#   < cv2.KeyPoint 0x7f8a38a5d720>,
#   < cv2.KeyPoint 0x7f8a38a5d750>,
#   < cv2.KeyPoint 0x7f8a38a5d780>,
#   < cv2.KeyPoint 0x7f8a38a5d7b0>,
#   < cv2.KeyPoint 0x7f8a38a5d7e0>,
#   < cv2.KeyPoint 0x7f8a38a5d810>,
#   < cv2.KeyPoint 0x7f8a38a5d870>,
#   < cv2.KeyPoint 0x7f8a38a5d090>,
#   < cv2.KeyPoint 0x7f8a38a5d8a0>,
#   < cv2.KeyPoint 0x7f8a38a5d900>,
#   < cv2.KeyPoint 0x7f8a38a5d930>,
#   < cv2.KeyPoint 0x7f8a38a5d630>,
#   < cv2.KeyPoint 0x7f8a38a5d960>,
#   < cv2.KeyPoint 0x7f8a38a5d690>,
#   < cv2.KeyPoint 0x7f8a38a5d990>,
#   < cv2.KeyPoint 0x7f8a38a5d9c0>,
#   < cv2.KeyPoint 0x7f8a38a5d9f0>,
#   < cv2.KeyPoint 0x7f8a38a5da20>,
#   < cv2.KeyPoint 0x7f8a38a5da50>,
#   < cv2.KeyPoint 0x7f8a38a5da80>,
#   < cv2.KeyPoint 0x7f8a38a5dab0>,
#   < cv2.KeyPoint 0x7f8a38a5dae0>,
#   < cv2.KeyPoint 0x7f8a38a5db10>,
#   < cv2.KeyPoint 0x7f8a38a5db40>,
#   < cv2.KeyPoint 0x7f8a38a5d570>,
#   < cv2.KeyPoint 0x7f8a38a5d540>,
#   < cv2.KeyPoint 0x7f8a38a5db70>,
#   < cv2.KeyPoint 0x7f8a38a5d600>,
#   < cv2.KeyPoint 0x7f8a38a5dba0>,
#   < cv2.KeyPoint 0x7f8a38a5dbd0>,
#   < cv2.KeyPoint 0x7f8a38a5dc00>,
#   < cv2.KeyPoint 0x7f8a38a5d660>,
#   < cv2.KeyPoint 0x7f8a38a5dc30>,
#   < cv2.KeyPoint 0x7f8a38a5d5d0>,
#   < cv2.KeyPoint 0x7f8a38a5d4b0>,
#   < cv2.KeyPoint 0x7f8a38a5d4e0>,
#   < cv2.KeyPoint 0x7f8a38a5d8d0>,
#   < cv2.KeyPoint 0x7f8a38a5d840>,
#   < cv2.KeyPoint 0x7f8a39142ed0>,
#   < cv2.KeyPoint 0x7f8a39142f00>,
#   < cv2.KeyPoint 0x7f8a39142f60>,
#   < cv2.KeyPoint 0x7f8a39142f30>,
#   < cv2.KeyPoint 0x7f8a39142bd0>,
#   < cv2.KeyPoint 0x7f8a39142ae0>,
#   < cv2.KeyPoint 0x7f8a4d0a3030>,
#   < cv2.KeyPoint 0x7f8a4d0a3060>,
#   < cv2.KeyPoint 0x7f8a4d0a3090>,
#   < cv2.KeyPoint 0x7f8a4d0a30c0>,
#   < cv2.KeyPoint 0x7f8a4d0a30f0>,
#   < cv2.KeyPoint 0x7f8a4d0a3120>,
#   < cv2.KeyPoint 0x7f8a4d0a3150>,
#   < cv2.KeyPoint 0x7f8a4d0a3180>,
#   < cv2.KeyPoint 0x7f8a4d0a31b0>,
#   < cv2.KeyPoint 0x7f8a4d0a3240>,
#   < cv2.KeyPoint 0x7f8a4d0a3270>,
#   < cv2.KeyPoint 0x7f8a4d0a32a0>,
#   < cv2.KeyPoint 0x7f8a4d0a32d0>,
#   < cv2.KeyPoint 0x7f8a4d0a3300>,
#   < cv2.KeyPoint 0x7f8a4d0a3330>,
#   < cv2.KeyPoint 0x7f8a4d0a3360>,
#   < cv2.KeyPoint 0x7f8a4d0a3390>,
#   < cv2.KeyPoint 0x7f8a4d0a33c0>,
#   < cv2.KeyPoint 0x7f8a4d0a33f0>,
#   < cv2.KeyPoint 0x7f8a4d0a3420>,
#   < cv2.KeyPoint 0x7f8a4d0a3450>,
#   < cv2.KeyPoint 0x7f8a4d0a3480>,
#   < cv2.KeyPoint 0x7f8a4d0a34b0>,
#   < cv2.KeyPoint 0x7f8a4d0a34e0>,
#   < cv2.KeyPoint 0x7f8a4d0a3570>,
#   < cv2.KeyPoint 0x7f8a4d0a35a0>,
#   < cv2.KeyPoint 0x7f8a4d0a31e0>,
#   < cv2.KeyPoint 0x7f8a4d0a35d0>,
#   < cv2.KeyPoint 0x7f8a4d0a3600>,
#   < cv2.KeyPoint 0x7f8a4d0a3630>,
#   < cv2.KeyPoint 0x7f8a4d0a3660>,
#   < cv2.KeyPoint 0x7f8a4d0a3690>,
#   < cv2.KeyPoint 0x7f8a4d0a36c0>,
#   < cv2.KeyPoint 0x7f8a4d0a36f0>,
#   < cv2.KeyPoint 0x7f8a4d0a3720>,
#   < cv2.KeyPoint 0x7f8a4d0a3750>,
#   < cv2.KeyPoint 0x7f8a4d0a3780>,
#   < cv2.KeyPoint 0x7f8a4d0a37b0>,
#   < cv2.KeyPoint 0x7f8a4d0a37e0>,
#   < cv2.KeyPoint 0x7f8a4d0a3810>,
#   < cv2.KeyPoint 0x7f8a4d0a3540>,
#   < cv2.KeyPoint 0x7f8a4d0a3840>,
#   < cv2.KeyPoint 0x7f8a4d0a3510>,
#   < cv2.KeyPoint 0x7f8a4d0a3870>,
#   < cv2.KeyPoint 0x7f8a4d0a38a0>,
#   < cv2.KeyPoint 0x7f8a4d0a38d0>,
#   < cv2.KeyPoint 0x7f8a4d0a3900>,
#   < cv2.KeyPoint 0x7f8a4d0a3960>,
#   < cv2.KeyPoint 0x7f8a4d0a3990>,
#   < cv2.KeyPoint 0x7f8a4d0a39c0>,
#   < cv2.KeyPoint 0x7f8a4d0a39f0>,
#   < cv2.KeyPoint 0x7f8a4d0a3a20>,
#   < cv2.KeyPoint 0x7f8a4d0a3a50>,
#   < cv2.KeyPoint 0x7f8a4d0a3a80>,
#   < cv2.KeyPoint 0x7f8a4d0a3ae0>,
#   < cv2.KeyPoint 0x7f8a4d0a3b10>,
#   < cv2.KeyPoint 0x7f8a4d0a3ab0>,
#   < cv2.KeyPoint 0x7f8a4d0a3b40>,
#   < cv2.KeyPoint 0x7f8a4d0a3ba0>,
#   < cv2.KeyPoint 0x7f8a4d0a3bd0>,
#   < cv2.KeyPoint 0x7f8a4d0a3c00>,
#   < cv2.KeyPoint 0x7f8a4d0a3c30>,
#   < cv2.KeyPoint 0x7f8a4d0a3c90>,
#   < cv2.KeyPoint 0x7f8a4d0a3cc0>,
#   < cv2.KeyPoint 0x7f8a4d0a3cf0>,
#   < cv2.KeyPoint 0x7f8a4d0a3d20>,
#   < cv2.KeyPoint 0x7f8a4d0a3d50>,
#   < cv2.KeyPoint 0x7f8a4d0a3d80>,
#   < cv2.KeyPoint 0x7f8a4d0a3db0>,
#   < cv2.KeyPoint 0x7f8a4d0a3de0>,
#   < cv2.KeyPoint 0x7f8a4d0a3c60>,
#   < cv2.KeyPoint 0x7f8a4d0a3930>,
#   < cv2.KeyPoint 0x7f8a4d0a3210>,
#   < cv2.KeyPoint 0x7f8a4d0a3b70>,
#   < cv2.KeyPoint 0x7f8a88afb600>,
#   < cv2.KeyPoint 0x7f8a88afb660>,
#   < cv2.KeyPoint 0x7f8a88afbb10>,
#   < cv2.KeyPoint 0x7f8a88afbf30>,
#   < cv2.KeyPoint 0x7f8a88afb630>,
#   < cv2.KeyPoint 0x7f8a88afb9c0>,
#   < cv2.KeyPoint 0x7f8a88afbae0>,
#   < cv2.KeyPoint 0x7f8a88afb690>,
#   < cv2.KeyPoint 0x7f8a88afbf90>,
#   < cv2.KeyPoint 0x7f8a88afbd80>,
#   < cv2.KeyPoint 0x7f8a889fd210>,
#   < cv2.KeyPoint 0x7f8a889fd1e0>,
#   < cv2.KeyPoint 0x7f8a889fdf30>,
#   < cv2.KeyPoint 0x7f8a889fdd50>,
#   < cv2.KeyPoint 0x7f8a889fdcf0>,
#   < cv2.KeyPoint 0x7f8a889fd180>,
#   < cv2.KeyPoint 0x7f8a889fd2d0>,
#   < cv2.KeyPoint 0x7f8a889fd1b0>,
#   < cv2.KeyPoint 0x7f8a889fd3f0>,
#   < cv2.KeyPoint 0x7f8a889fdde0>,
#   < cv2.KeyPoint 0x7f8a889fd750>,
#   < cv2.KeyPoint 0x7f8a889fd840>,
#   < cv2.KeyPoint 0x7f8a889fda50>,
#   < cv2.KeyPoint 0x7f8a889fda20>,
#   < cv2.KeyPoint 0x7f8a889fd600>,
#   < cv2.KeyPoint 0x7f8a889fdc60>,
#   < cv2.KeyPoint 0x7f8a889fd900>,
#   < cv2.KeyPoint 0x7f8a88adca50>,
#   < cv2.KeyPoint 0x7f8a88adca20>,
#   < cv2.KeyPoint 0x7f8a88adc810>,
#   < cv2.KeyPoint 0x7f8a88adcab0>,
#   < cv2.KeyPoint 0x7f8a88adcf30>,
#   < cv2.KeyPoint 0x7f8a88adcc00>,
#   < cv2.KeyPoint 0x7f8a88adcba0>,
#   < cv2.KeyPoint 0x7f8a88adc4b0>,
#   < cv2.KeyPoint 0x7f8a88adcb70>,
#   < cv2.KeyPoint 0x7f8a88adca80>,
#   < cv2.KeyPoint 0x7f8a4d095030>,
#   < cv2.KeyPoint 0x7f8a4d0950c0>,
#   < cv2.KeyPoint 0x7f8a4d0950f0>,
#   < cv2.KeyPoint 0x7f8a4d095120>,
#   < cv2.KeyPoint 0x7f8a4d095150>,
#   < cv2.KeyPoint 0x7f8a4d095180>,
#   < cv2.KeyPoint 0x7f8a4d0951b0>,
#   < cv2.KeyPoint 0x7f8a4d0951e0>,
#   < cv2.KeyPoint 0x7f8a4d095210>,
#   < cv2.KeyPoint 0x7f8a4d095240>,
#   < cv2.KeyPoint 0x7f8a4d095270>,
#   < cv2.KeyPoint 0x7f8a4d0952a0>,
#   < cv2.KeyPoint 0x7f8a4d0952d0>,
#   < cv2.KeyPoint 0x7f8a4d095300>,
#   < cv2.KeyPoint 0x7f8a4d095330>,
#   < cv2.KeyPoint 0x7f8a4d095360>,
#   < cv2.KeyPoint 0x7f8a4d0953c0>,
#   < cv2.KeyPoint 0x7f8a4d0953f0>,
#   < cv2.KeyPoint 0x7f8a4d095420>,
#   < cv2.KeyPoint 0x7f8a4d095450>,
#   < cv2.KeyPoint 0x7f8a4d095480>,
#   < cv2.KeyPoint 0x7f8a4d0954b0>,
#   < cv2.KeyPoint 0x7f8a4d0954e0>,
#   < cv2.KeyPoint 0x7f8a4d095540>,
#   < cv2.KeyPoint 0x7f8a4d095570>,
#   < cv2.KeyPoint 0x7f8a4d095510>,
#   < cv2.KeyPoint 0x7f8a4d0955d0>,
#   < cv2.KeyPoint 0x7f8a4d095600>,
#   < cv2.KeyPoint 0x7f8a4d0955a0>,
#   < cv2.KeyPoint 0x7f8a4d095630>,
#   < cv2.KeyPoint 0x7f8a4d095660>,
#   < cv2.KeyPoint 0x7f8a4d0956f0>,
#   < cv2.KeyPoint 0x7f8a4d095720>,
#   < cv2.KeyPoint 0x7f8a4d095a50>,
#   < cv2.KeyPoint 0x7f8a4d095690>,
#   < cv2.KeyPoint 0x7f8a4d095390>,
#   < cv2.KeyPoint 0x7f8a4d095090>,
#   < cv2.KeyPoint 0x7f8a4d0956c0>,
#   < cv2.KeyPoint 0x7f8a4d095060>,
#   < cv2.KeyPoint 0x7f8a391a1780>,
#   < cv2.KeyPoint 0x7f8a391a1720>,
#   < cv2.KeyPoint 0x7f8a391a1db0>,
#   < cv2.KeyPoint 0x7f8a391a1cf0>,
#   < cv2.KeyPoint 0x7f8a391a1c00>,
#   < cv2.KeyPoint 0x7f8a391a1bd0>,
#   < cv2.KeyPoint 0x7f8a391a1b10>,
#   < cv2.KeyPoint 0x7f8a391a1ab0>,
#   < cv2.KeyPoint 0x7f8a391a1a50>,
#   < cv2.KeyPoint 0x7f8a391a19f0>,
#   < cv2.KeyPoint 0x7f8a391a19c0>,
#   < cv2.KeyPoint 0x7f8a391a1900>,
#   < cv2.KeyPoint 0x7f8a391a18a0>,
#   < cv2.KeyPoint 0x7f8a391a1840>,
#   < cv2.KeyPoint 0x7f8a391a17e0>,
#   < cv2.KeyPoint 0x7f8a391a17b0>,
#   < cv2.KeyPoint 0x7f8a391a1120>,
#   < cv2.KeyPoint 0x7f8a391a1240>,
#   < cv2.KeyPoint 0x7f8a391a12a0>,
#   < cv2.KeyPoint 0x7f8a391a1480>,
#   < cv2.KeyPoint 0x7f8a391a13c0>,
#   < cv2.KeyPoint 0x7f8a391a16c0>,
#   < cv2.KeyPoint 0x7f8a391a1de0>,
#   < cv2.KeyPoint 0x7f8a391a1d50>,
#   < cv2.KeyPoint 0x7f8a391a1e40>,
#   < cv2.KeyPoint 0x7f8a391a1e70>,
#   < cv2.KeyPoint 0x7f8a391a1f30>,
#   < cv2.KeyPoint 0x7f8a391a1f90>,
#   < cv2.KeyPoint 0x7f8a391a1d80>,
#   < cv2.KeyPoint 0x7f8a391a1ba0>,
#   < cv2.KeyPoint 0x7f8a391a1d20>,
#   < cv2.KeyPoint 0x7f8a391a15d0>,
#   < cv2.KeyPoint 0x7f8a391a1ea0>,
#   < cv2.KeyPoint 0x7f8a391a1e10>,
#   < cv2.KeyPoint 0x7f8a391a1f60>,
#   < cv2.KeyPoint 0x7f8a391a1ed0>,
#   < cv2.KeyPoint 0x7f8a391a1fc0>,
#   < cv2.KeyPoint 0x7f8a391a1f00>,
#   < cv2.KeyPoint 0x7f8a888cd480>,
#   < cv2.KeyPoint 0x7f8a888cd450>,
#   < cv2.KeyPoint 0x7f8a888cd390>,
#   < cv2.KeyPoint 0x7f8a888cd330>,
#   < cv2.KeyPoint 0x7f8a888cd2d0>,
#   < cv2.KeyPoint 0x7f8a888cd270>,
#   < cv2.KeyPoint 0x7f8a888cd240>,
#   < cv2.KeyPoint 0x7f8a888cd180>,
#   < cv2.KeyPoint 0x7f8a888cd120>,
#   < cv2.KeyPoint 0x7f8a888cd0c0>,
#   < cv2.KeyPoint 0x7f8a888cd060>,
#   < cv2.KeyPoint 0x7f8a888cd030>,
#   < cv2.KeyPoint 0x7f8a888cd510>,
#   < cv2.KeyPoint 0x7f8a888cd4e0>,
#   < cv2.KeyPoint 0x7f8a888cd540>,
#   < cv2.KeyPoint 0x7f8a888cd570>,
#   < cv2.KeyPoint 0x7f8a888cd5a0>,
#   < cv2.KeyPoint 0x7f8a888cd600>,
#   < cv2.KeyPoint 0x7f8a888cd630>,
#   < cv2.KeyPoint 0x7f8a888cd660>,
#   < cv2.KeyPoint 0x7f8a888cd6c0>,
#   < cv2.KeyPoint 0x7f8a888cd6f0>,
#   < cv2.KeyPoint 0x7f8a888cd780>,
#   < cv2.KeyPoint 0x7f8a888cd7b0>,
#   < cv2.KeyPoint 0x7f8a888cd7e0>,
#   < cv2.KeyPoint 0x7f8a888cd810>,
#   < cv2.KeyPoint 0x7f8a888cd840>,
#   < cv2.KeyPoint 0x7f8a888cd870>,
#   < cv2.KeyPoint 0x7f8a888cd8a0>,
#   < cv2.KeyPoint 0x7f8a888cd8d0>,
#   < cv2.KeyPoint 0x7f8a888cd5d0>,
#   < cv2.KeyPoint 0x7f8a888cd900>,
#   < cv2.KeyPoint 0x7f8a888cd930>,
#   < cv2.KeyPoint 0x7f8a888cd960>,
#   < cv2.KeyPoint 0x7f8a888cd690>,
#   < cv2.KeyPoint 0x7f8a888cd990>,
#   < cv2.KeyPoint 0x7f8a888cd9c0>,
#   < cv2.KeyPoint 0x7f8a888cd720>,
#   < cv2.KeyPoint 0x7f8a888cd750>,
#   < cv2.KeyPoint 0x7f8a888cd9f0>,
#   < cv2.KeyPoint 0x7f8a888cda20>,
#   < cv2.KeyPoint 0x7f8a888cda50>,
#   < cv2.KeyPoint 0x7f8a888cda80>,
#   < cv2.KeyPoint 0x7f8a888cdab0>,
#   < cv2.KeyPoint 0x7f8a888cdae0>,
#   < cv2.KeyPoint 0x7f8a888cdb10>,
#   < cv2.KeyPoint 0x7f8a888cdb40>,
#   < cv2.KeyPoint 0x7f8a888cdba0>,
#   < cv2.KeyPoint 0x7f8a888cdb70>,
#   < cv2.KeyPoint 0x7f8a888cdbd0>,
#   < cv2.KeyPoint 0x7f8a888cdc30>,
#   < cv2.KeyPoint 0x7f8a888cdc00>,
#   < cv2.KeyPoint 0x7f8a888cdc60>,
#   < cv2.KeyPoint 0x7f8a888cdc90>,
#   < cv2.KeyPoint 0x7f8a888cdcc0>,
#   < cv2.KeyPoint 0x7f8a888cdcf0>,
#   < cv2.KeyPoint 0x7f8a888cdd20>,
#   < cv2.KeyPoint 0x7f8a888cdd50>,
#   < cv2.KeyPoint 0x7f8a888cdd80>,
#   < cv2.KeyPoint 0x7f8a888cddb0>,
#   < cv2.KeyPoint 0x7f8a888cdde0>,
#   < cv2.KeyPoint 0x7f8a888cde10>,
#   < cv2.KeyPoint 0x7f8a888cde40>,
#   < cv2.KeyPoint 0x7f8a888cde70>,
#   < cv2.KeyPoint 0x7f8a888cdea0>,
#   < cv2.KeyPoint 0x7f8a888cdf00>,
#   < cv2.KeyPoint 0x7f8a888cdf60>,
#   < cv2.KeyPoint 0x7f8a888cdf90>,
#   < cv2.KeyPoint 0x7f8a888cdf30>,
#   < cv2.KeyPoint 0x7f8a888cded0>,
#   < cv2.KeyPoint 0x7f8a888cdfc0>,
#   < cv2.KeyPoint 0x7f8a4d098030>,
#   < cv2.KeyPoint 0x7f8a4d098060>,
#   < cv2.KeyPoint 0x7f8a4d098090>,
#   < cv2.KeyPoint 0x7f8a4d0980c0>,
#   < cv2.KeyPoint 0x7f8a4d0980f0>,
#   < cv2.KeyPoint 0x7f8a4d098120>,
#   < cv2.KeyPoint 0x7f8a4d098150>,
#   < cv2.KeyPoint 0x7f8a4d098180>,
#   < cv2.KeyPoint 0x7f8a4d0981b0>,
#   < cv2.KeyPoint 0x7f8a4d0981e0>,
#   < cv2.KeyPoint 0x7f8a4d098210>,
#   < cv2.KeyPoint 0x7f8a4d098270>,
#   < cv2.KeyPoint 0x7f8a4d0982a0>,
#   < cv2.KeyPoint 0x7f8a4d0982d0>,
#   < cv2.KeyPoint 0x7f8a4d098300>,
#   < cv2.KeyPoint 0x7f8a4d098330>,
#   < cv2.KeyPoint 0x7f8a4d098360>,
#   < cv2.KeyPoint 0x7f8a4d098390>,
#   < cv2.KeyPoint 0x7f8a4d0983c0>,
#   < cv2.KeyPoint 0x7f8a4d0983f0>,
#   < cv2.KeyPoint 0x7f8a4d098420>,
#   < cv2.KeyPoint 0x7f8a4d098450>,
#   < cv2.KeyPoint 0x7f8a4d098480>,
#   < cv2.KeyPoint 0x7f8a4d0984b0>,
#   < cv2.KeyPoint 0x7f8a4d0984e0>,
#   < cv2.KeyPoint 0x7f8a4d098510>,
#   < cv2.KeyPoint 0x7f8a4d098540>,
#   < cv2.KeyPoint 0x7f8a4d098570>,
#   < cv2.KeyPoint 0x7f8a4d098240>,
#   < cv2.KeyPoint 0x7f8a4d0985a0>,
#   < cv2.KeyPoint 0x7f8a4d0985d0>,
#   < cv2.KeyPoint 0x7f8a4d098600>,
#   < cv2.KeyPoint 0x7f8a4d098630>,
#   < cv2.KeyPoint 0x7f8a4d098660>,
#   < cv2.KeyPoint 0x7f8a4d098690>,
#   < cv2.KeyPoint 0x7f8a4d0986c0>,
#   < cv2.KeyPoint 0x7f8a4d0986f0>,
#   < cv2.KeyPoint 0x7f8a4d098720>,
#   < cv2.KeyPoint 0x7f8a4d098750>,
#   < cv2.KeyPoint 0x7f8a4d098780>,
#   < cv2.KeyPoint 0x7f8a4d0987b0>,
#   < cv2.KeyPoint 0x7f8a4d0987e0>,
#   < cv2.KeyPoint 0x7f8a4d098810>,
#   < cv2.KeyPoint 0x7f8a4d098840>,
#   < cv2.KeyPoint 0x7f8a4d0988a0>,
#   < cv2.KeyPoint 0x7f8a4d098900>,
#   < cv2.KeyPoint 0x7f8a4d098930>,
#   < cv2.KeyPoint 0x7f8a4d098960>,
#   < cv2.KeyPoint 0x7f8a4d098990>,
#   < cv2.KeyPoint 0x7f8a4d0989c0>,
#   < cv2.KeyPoint 0x7f8a4d0989f0>,
#   < cv2.KeyPoint 0x7f8a4d098a20>,
#   < cv2.KeyPoint 0x7f8a4d098a50>,
#   < cv2.KeyPoint 0x7f8a4d098a80>,
#   < cv2.KeyPoint 0x7f8a4d098ab0>,
#   < cv2.KeyPoint 0x7f8a4d098ae0>,
#   < cv2.KeyPoint 0x7f8a4d098b10>,
#   < cv2.KeyPoint 0x7f8a4d098b40>,
#   < cv2.KeyPoint 0x7f8a4d098b70>,
#   < cv2.KeyPoint 0x7f8a4d098ba0>,
#   < cv2.KeyPoint 0x7f8a4d098bd0>,
#   < cv2.KeyPoint 0x7f8a4d0988d0>,
#   < cv2.KeyPoint 0x7f8a4d098c00>,
#   < cv2.KeyPoint 0x7f8a4d098c30>,
#   < cv2.KeyPoint 0x7f8a4d098c60>,
#   < cv2.KeyPoint 0x7f8a4d098c90>,
#   < cv2.KeyPoint 0x7f8a4d098cc0>,
#   < cv2.KeyPoint 0x7f8a4d098cf0>,
#   < cv2.KeyPoint 0x7f8a4d098d20>,
#   < cv2.KeyPoint 0x7f8a4d098d50>,
#   < cv2.KeyPoint 0x7f8a4d098d80>,
#   < cv2.KeyPoint 0x7f8a4d098db0>,
#   < cv2.KeyPoint 0x7f8a4d098de0>,
#   < cv2.KeyPoint 0x7f8a4d098e10>,
#   < cv2.KeyPoint 0x7f8a4d098e40>,
#   < cv2.KeyPoint 0x7f8a4d098ea0>,
#   < cv2.KeyPoint 0x7f8a4d098e70>,
#   < cv2.KeyPoint 0x7f8a4d098ed0>,
#   < cv2.KeyPoint 0x7f8a38718f00>,
#   < cv2.KeyPoint 0x7f8a88bd45d0>,
#   < cv2.KeyPoint 0x7f8a88a6cc00>,
#   < cv2.KeyPoint 0x7f8a88a6cba0>,
#   < cv2.KeyPoint 0x7f8a88a6cb40>,
#   < cv2.KeyPoint 0x7f8a88a6c5d0>,
#   < cv2.KeyPoint 0x7f8a88a6c600>,
#   < cv2.KeyPoint 0x7f8a88a6cd20>,
#   < cv2.KeyPoint 0x7f8a88a6c660>,
#   < cv2.KeyPoint 0x7f8a88a6c630>,
#   < cv2.KeyPoint 0x7f8a88a6c7e0>,
#   < cv2.KeyPoint 0x7f8a88a6cdb0>,
#   < cv2.KeyPoint 0x7f8a88a6cab0>,
#   < cv2.KeyPoint 0x7f8a88a6c8d0>,
#   < cv2.KeyPoint 0x7f8a88a6c9f0>,
#   < cv2.KeyPoint 0x7f8a88a6cd50>,
#   < cv2.KeyPoint 0x7f8a4d1317e0>,
#   < cv2.KeyPoint 0x7f8a4d1317b0>,
#   < cv2.KeyPoint 0x7f8a4d1316f0>,
#   < cv2.KeyPoint 0x7f8a4d131690>,
#   < cv2.KeyPoint 0x7f8a4d131780>,
#   < cv2.KeyPoint 0x7f8a4d131630>,
#   < cv2.KeyPoint 0x7f8a4d1315d0>,
#   < cv2.KeyPoint 0x7f8a4d1315a0>,
#   < cv2.KeyPoint 0x7f8a4d1314e0>,
#   < cv2.KeyPoint 0x7f8a4d131480>,
#   < cv2.KeyPoint 0x7f8a4d131420>,
#   < cv2.KeyPoint 0x7f8a4d1313c0>,
#   < cv2.KeyPoint 0x7f8a4d131390>,
#   < cv2.KeyPoint 0x7f8a4d1312d0>,
#   < cv2.KeyPoint 0x7f8a4d131270>,
#   < cv2.KeyPoint 0x7f8a4d131210>,
#   < cv2.KeyPoint 0x7f8a4d1311b0>,
#   < cv2.KeyPoint 0x7f8a4d131180>,
#   < cv2.KeyPoint 0x7f8a4d1310c0>,
#   < cv2.KeyPoint 0x7f8a4d131060>,
#   < cv2.KeyPoint 0x7f8a4d131810>,
#   < cv2.KeyPoint 0x7f8a4d131840>,
#   < cv2.KeyPoint 0x7f8a4d131870>,
#   < cv2.KeyPoint 0x7f8a4d1318a0>,
#   < cv2.KeyPoint 0x7f8a4d1318d0>,
#   < cv2.KeyPoint 0x7f8a4d131900>,
#   < cv2.KeyPoint 0x7f8a4d131930>,
#   < cv2.KeyPoint 0x7f8a4d131960>,
#   < cv2.KeyPoint 0x7f8a4d131990>,
#   < cv2.KeyPoint 0x7f8a4d1319c0>,
#   < cv2.KeyPoint 0x7f8a4d1319f0>,
#   < cv2.KeyPoint 0x7f8a4d131a20>,
#   < cv2.KeyPoint 0x7f8a4d131a50>,
#   < cv2.KeyPoint 0x7f8a4d131a80>,
#   < cv2.KeyPoint 0x7f8a4d131ab0>,
#   < cv2.KeyPoint 0x7f8a4d131ae0>,
#   < cv2.KeyPoint 0x7f8a4d131b10>,
#   < cv2.KeyPoint 0x7f8a4d131b40>,
#   < cv2.KeyPoint 0x7f8a4d131b70>,
#   < cv2.KeyPoint 0x7f8a4d131ba0>,
#   < cv2.KeyPoint 0x7f8a4d131bd0>,
#   < cv2.KeyPoint 0x7f8a4d131c00>,
#   < cv2.KeyPoint 0x7f8a4d131c30>,
#   < cv2.KeyPoint 0x7f8a4d131c60>,
#   < cv2.KeyPoint 0x7f8a4d131c90>,
#   < cv2.KeyPoint 0x7f8a4d131cc0>,
#   < cv2.KeyPoint 0x7f8a4d131cf0>,
#   < cv2.KeyPoint 0x7f8a4d131d20>,
#   < cv2.KeyPoint 0x7f8a4d131d50>,
#   < cv2.KeyPoint 0x7f8a4d131d80>,
#   < cv2.KeyPoint 0x7f8a4d131db0>,
#   < cv2.KeyPoint 0x7f8a4d131de0>,
#   < cv2.KeyPoint 0x7f8a4d131e10>,
#   < cv2.KeyPoint 0x7f8a4d131e40>,
#   < cv2.KeyPoint 0x7f8a4d131e70>,
#   < cv2.KeyPoint 0x7f8a4d131ea0>,
#   < cv2.KeyPoint 0x7f8a4d131ed0>,
#   < cv2.KeyPoint 0x7f8a4d131f00>,
#   < cv2.KeyPoint 0x7f8a4d131f30>,
#   < cv2.KeyPoint 0x7f8a4d131f60>,
#   < cv2.KeyPoint 0x7f8a4d131f90>,
#   < cv2.KeyPoint 0x7f8a4d131fc0>,
#   < cv2.KeyPoint 0x7f8a38bfd030>,
#   < cv2.KeyPoint 0x7f8a38bfd060>,
#   < cv2.KeyPoint 0x7f8a38bfd090>,
#   < cv2.KeyPoint 0x7f8a38bfd0c0>,
#   < cv2.KeyPoint 0x7f8a38bfd0f0>,
#   < cv2.KeyPoint 0x7f8a38bfd120>,
#   < cv2.KeyPoint 0x7f8a38bfd150>,
#   < cv2.KeyPoint 0x7f8a38bfd180>,
#   < cv2.KeyPoint 0x7f8a38bfd1b0>,
#   < cv2.KeyPoint 0x7f8a38bfd1e0>,
#   < cv2.KeyPoint 0x7f8a38bfd210>,
#   < cv2.KeyPoint 0x7f8a38bfd240>,
#   < cv2.KeyPoint 0x7f8a38bfd270>,
#   < cv2.KeyPoint 0x7f8a38bfd2a0>,
#   < cv2.KeyPoint 0x7f8a38bfd2d0>,
#   < cv2.KeyPoint 0x7f8a38bfd300>,
#   < cv2.KeyPoint 0x7f8a38bfd330>,
#   < cv2.KeyPoint 0x7f8a38bfd360>,
#   < cv2.KeyPoint 0x7f8a38bfd390>,
#   < cv2.KeyPoint 0x7f8a38bfd3c0>,
#   < cv2.KeyPoint 0x7f8a38bfd3f0>,
#   < cv2.KeyPoint 0x7f8a38bfd420>,
#   < cv2.KeyPoint 0x7f8a38bfd450>,
#   < cv2.KeyPoint 0x7f8a38bfd480>,
#   < cv2.KeyPoint 0x7f8a38bfd4b0>,
#   < cv2.KeyPoint 0x7f8a38bfd4e0>,
#   < cv2.KeyPoint 0x7f8a38bfd510>,
#   < cv2.KeyPoint 0x7f8a38bfd540>,
#   < cv2.KeyPoint 0x7f8a38bfd570>,
#   < cv2.KeyPoint 0x7f8a38bfd5a0>,
#   < cv2.KeyPoint 0x7f8a38bfd5d0>,
#   < cv2.KeyPoint 0x7f8a38bfd600>,
#   < cv2.KeyPoint 0x7f8a38bfd630>,
#   < cv2.KeyPoint 0x7f8a38bfd660>,
#   < cv2.KeyPoint 0x7f8a38bfd690>,
#   < cv2.KeyPoint 0x7f8a38bfd6c0>,
#   < cv2.KeyPoint 0x7f8a38bfd6f0>,
#   < cv2.KeyPoint 0x7f8a38bfd720>,
#   < cv2.KeyPoint 0x7f8a38bfd750>,
#   < cv2.KeyPoint 0x7f8a38bfd780>,
#   < cv2.KeyPoint 0x7f8a38bfd7b0>,
#   < cv2.KeyPoint 0x7f8a38bfd7e0>,
#   < cv2.KeyPoint 0x7f8a38bfd810>,
#   < cv2.KeyPoint 0x7f8a38bfd840>,
#   < cv2.KeyPoint 0x7f8a38bfd870>,
#   < cv2.KeyPoint 0x7f8a38bfd8a0>,
#   < cv2.KeyPoint 0x7f8a38bfd8d0>,
#   < cv2.KeyPoint 0x7f8a38bfdc00>,
#   < cv2.KeyPoint 0x7f8a88ef44b0>,
#   < cv2.KeyPoint 0x7f8a88ef4090>,
#   < cv2.KeyPoint 0x7f8a88ef4360>,
#   < cv2.KeyPoint 0x7f8a88ef44e0>,
#   < cv2.KeyPoint 0x7f8a88ef4210>,
#   < cv2.KeyPoint 0x7f8a88ef4600>,
#   < cv2.KeyPoint 0x7f8a88ef4330>,
#   < cv2.KeyPoint 0x7f8a88ef45d0>,
#   < cv2.KeyPoint 0x7f8a88ef41e0>,
#   < cv2.KeyPoint 0x7f8a88ef42d0>,
#   < cv2.KeyPoint 0x7f8a88ef4420>,
#   < cv2.KeyPoint 0x7f8a88ef4510>,
#   < cv2.KeyPoint 0x7f8a88ef4150>,
#   < cv2.KeyPoint 0x7f8a88ef43f0>,
#   < cv2.KeyPoint 0x7f8a88ef4480>,
#   < cv2.KeyPoint 0x7f8a88ef43c0>,
#   < cv2.KeyPoint 0x7f8a88ef41b0>,
#   < cv2.KeyPoint 0x7f8a88ef4570>,
#   < cv2.KeyPoint 0x7f8a88ef4300>,
#   < cv2.KeyPoint 0x7f8a88ef40f0>,
#   < cv2.KeyPoint 0x7f8a88ef4540>,
#   < cv2.KeyPoint 0x7f8a389c7cc0>,
#   < cv2.KeyPoint 0x7f8a389c79c0>,
#   < cv2.KeyPoint 0x7f8a389c7090>,
#   < cv2.KeyPoint 0x7f8a389c76c0>,
#   < cv2.KeyPoint 0x7f8a389c7780>,
#   < cv2.KeyPoint 0x7f8a389c7870>,
#   < cv2.KeyPoint 0x7f8a389c7930>,
#   < cv2.KeyPoint 0x7f8a389c7b40>,
#   < cv2.KeyPoint 0x7f8a389c78d0>,
#   < cv2.KeyPoint 0x7f8a389c7a20>,
#   < cv2.KeyPoint 0x7f8a389c7d80>,
#   < cv2.KeyPoint 0x7f8a389c7de0>,
#   < cv2.KeyPoint 0x7f8a389c7900>,
#   < cv2.KeyPoint 0x7f8a389c7f00>,
#   < cv2.KeyPoint 0x7f8a389c7f60>,
#   < cv2.KeyPoint 0x7f8a389c73f0>,
#   < cv2.KeyPoint 0x7f8a389c7420>,
#   < cv2.KeyPoint 0x7f8a389c7450>,
#   < cv2.KeyPoint 0x7f8a389c73c0>,
#   < cv2.KeyPoint 0x7f8a387ae210>,
#   < cv2.KeyPoint 0x7f8a387ae1e0>,
#   < cv2.KeyPoint 0x7f8a387ae120>,
#   < cv2.KeyPoint 0x7f8a387ae0c0>,
#   < cv2.KeyPoint 0x7f8a387ae060>,
#   < cv2.KeyPoint 0x7f8a387ae360>,
#   < cv2.KeyPoint 0x7f8a387ae3c0>,
#   < cv2.KeyPoint 0x7f8a387ae300>,
#   < cv2.KeyPoint 0x7f8a387ae450>,
#   < cv2.KeyPoint 0x7f8a387ae3f0>,
#   < cv2.KeyPoint 0x7f8a387ae420>,
#   < cv2.KeyPoint 0x7f8a387ae4b0>,
#   < cv2.KeyPoint 0x7f8a387ae480>,
#   < cv2.KeyPoint 0x7f8a387ae330>,
#   < cv2.KeyPoint 0x7f8a387ae4e0>,
#   < cv2.KeyPoint 0x7f8a387ae510>,
#   < cv2.KeyPoint 0x7f8a387ae540>,
#   < cv2.KeyPoint 0x7f8a387ae570>,
#   < cv2.KeyPoint 0x7f8a387ae5a0>,
#   < cv2.KeyPoint 0x7f8a387ae5d0>,
#   < cv2.KeyPoint 0x7f8a387ae600>,
#   < cv2.KeyPoint 0x7f8a387ae630>,
#   < cv2.KeyPoint 0x7f8a387ae660>,
#   < cv2.KeyPoint 0x7f8a387ae690>,
#   < cv2.KeyPoint 0x7f8a387ae6c0>,
#   < cv2.KeyPoint 0x7f8a387ae6f0>,
#   < cv2.KeyPoint 0x7f8a387ae720>,
#   < cv2.KeyPoint 0x7f8a387ae750>,
#   < cv2.KeyPoint 0x7f8a387ae780>,
#   < cv2.KeyPoint 0x7f8a387ae7b0>,
#   < cv2.KeyPoint 0x7f8a387ae7e0>,
#   < cv2.KeyPoint 0x7f8a387ae810>,
#   < cv2.KeyPoint 0x7f8a387ae840>,
#   < cv2.KeyPoint 0x7f8a387ae870>,
#   < cv2.KeyPoint 0x7f8a387ae8a0>,
#   < cv2.KeyPoint 0x7f8a387ae8d0>,
#   < cv2.KeyPoint 0x7f8a387ae900>,
#   < cv2.KeyPoint 0x7f8a387ae930>,
#   < cv2.KeyPoint 0x7f8a387ae960>,
#   < cv2.KeyPoint 0x7f8a387ae990>,
#   < cv2.KeyPoint 0x7f8a387ae9c0>,
#   < cv2.KeyPoint 0x7f8a387ae9f0>,
#   < cv2.KeyPoint 0x7f8a387aea20>,
#   < cv2.KeyPoint 0x7f8a387aea50>,
#   < cv2.KeyPoint 0x7f8a387aea80>,
#   < cv2.KeyPoint 0x7f8a387aeab0>,
#   < cv2.KeyPoint 0x7f8a387aeae0>,
#   < cv2.KeyPoint 0x7f8a387aeb10>,
#   < cv2.KeyPoint 0x7f8a387aeb40>,
#   < cv2.KeyPoint 0x7f8a387aeb70>,
#   < cv2.KeyPoint 0x7f8a387aeba0>,
#   < cv2.KeyPoint 0x7f8a387aebd0>,
#   < cv2.KeyPoint 0x7f8a387aec00>,
#   < cv2.KeyPoint 0x7f8a387aec30>,
#   < cv2.KeyPoint 0x7f8a387aec60>,
#   < cv2.KeyPoint 0x7f8a387aec90>,
#   < cv2.KeyPoint 0x7f8a387aecc0>,
#   < cv2.KeyPoint 0x7f8a387aecf0>,
#   < cv2.KeyPoint 0x7f8a387aed20>,
#   < cv2.KeyPoint 0x7f8a387aed50>,
#   < cv2.KeyPoint 0x7f8a387aed80>,
#   < cv2.KeyPoint 0x7f8a387aedb0>,
#   < cv2.KeyPoint 0x7f8a387aede0>,
#   < cv2.KeyPoint 0x7f8a387aee10>,
#   < cv2.KeyPoint 0x7f8a387aee40>,
#   < cv2.KeyPoint 0x7f8a387aee70>,
#   < cv2.KeyPoint 0x7f8a387aeea0>,
#   < cv2.KeyPoint 0x7f8a387aeed0>,
#   < cv2.KeyPoint 0x7f8a387aef00>,
#   < cv2.KeyPoint 0x7f8a387aef30>,
#   < cv2.KeyPoint 0x7f8a387aef60>,
#   < cv2.KeyPoint 0x7f8a387aef90>,
#   < cv2.KeyPoint 0x7f8a387aefc0>,
#   < cv2.KeyPoint 0x7f8a4d0ab030>,
#   < cv2.KeyPoint 0x7f8a4d0ab060>,
#   < cv2.KeyPoint 0x7f8a4d0ab090>,
#   < cv2.KeyPoint 0x7f8a4d0ab0c0>,
#   < cv2.KeyPoint 0x7f8a4d0ab0f0>,
#   < cv2.KeyPoint 0x7f8a4d0ab120>,
#   < cv2.KeyPoint 0x7f8a4d0ab150>,
#   < cv2.KeyPoint 0x7f8a4d0ab180>,
#   < cv2.KeyPoint 0x7f8a4d0ab1b0>,
#   < cv2.KeyPoint 0x7f8a4d0ab1e0>,
#   < cv2.KeyPoint 0x7f8a4d0ab210>,
#   < cv2.KeyPoint 0x7f8a4d0ab240>,
#   < cv2.KeyPoint 0x7f8a4d0ab270>,
#   < cv2.KeyPoint 0x7f8a4d0ab2a0>,
#   < cv2.KeyPoint 0x7f8a4d0ab2d0>,
#   < cv2.KeyPoint 0x7f8a4d0ab300>,
#   < cv2.KeyPoint 0x7f8a4d0ab330>,
#   < cv2.KeyPoint 0x7f8a4d0ab360>,
#   < cv2.KeyPoint 0x7f8a4d0ab390>,
#   < cv2.KeyPoint 0x7f8a4d0ab3c0>,
#   < cv2.KeyPoint 0x7f8a4d0ab3f0>,
#   < cv2.KeyPoint 0x7f8a4d0ab420>,
#   < cv2.KeyPoint 0x7f8a4d0ab450>,
#   < cv2.KeyPoint 0x7f8a4d0ab480>,
#   < cv2.KeyPoint 0x7f8a4d0ab4b0>,
#   < cv2.KeyPoint 0x7f8a4d0ab4e0>,
#   < cv2.KeyPoint 0x7f8a4d0ab510>,
#   < cv2.KeyPoint 0x7f8a4d0ab540>,
#   < cv2.KeyPoint 0x7f8a4d0ab570>,
#   < cv2.KeyPoint 0x7f8a4d0ab5a0>,
#   < cv2.KeyPoint 0x7f8a4d0ab5d0>,
#   < cv2.KeyPoint 0x7f8a4d0ab600>,
#   < cv2.KeyPoint 0x7f8a4d0ab630>,
#   < cv2.KeyPoint 0x7f8a4d0ab660>,
#   < cv2.KeyPoint 0x7f8a4d0ab690>,
#   < cv2.KeyPoint 0x7f8a4d0ab6c0>,
#   < cv2.KeyPoint 0x7f8a4d0ab6f0>,
#   < cv2.KeyPoint 0x7f8a4d0ab720>,
#   < cv2.KeyPoint 0x7f8a4d0ab750>,
#   < cv2.KeyPoint 0x7f8a4d0ab780>,
#   < cv2.KeyPoint 0x7f8a4d0ab7b0>,
#   < cv2.KeyPoint 0x7f8a4d0ab7e0>,
#   < cv2.KeyPoint 0x7f8a4d0ab810>,
#   < cv2.KeyPoint 0x7f8a4d0ab840>,
#   < cv2.KeyPoint 0x7f8a4d0ab870>,
#   < cv2.KeyPoint 0x7f8a4d0ab8a0>,
#   < cv2.KeyPoint 0x7f8a4d0ab8d0>,
#   < cv2.KeyPoint 0x7f8a4d0ab900>,
#   < cv2.KeyPoint 0x7f8a4d0ab930>,
#   < cv2.KeyPoint 0x7f8a4d0ab960>,
#   < cv2.KeyPoint 0x7f8a4d0ab990>,
#   < cv2.KeyPoint 0x7f8a4d0ab9c0>,
#   < cv2.KeyPoint 0x7f8a4d0ab9f0>,
#   < cv2.KeyPoint 0x7f8a4d0aba20>,
#   < cv2.KeyPoint 0x7f8a4d0aba50>,
#   < cv2.KeyPoint 0x7f8a4d0aba80>,
#   < cv2.KeyPoint 0x7f8a4d0abab0>,
#   < cv2.KeyPoint 0x7f8a4d0abae0>,
#   < cv2.KeyPoint 0x7f8a4d0abb10>,
#   < cv2.KeyPoint 0x7f8a4d0abb40>,
#   < cv2.KeyPoint 0x7f8a4d0abb70>,
#   < cv2.KeyPoint 0x7f8a4d0abba0>,
#   < cv2.KeyPoint 0x7f8a4d0abbd0>,
#   < cv2.KeyPoint 0x7f8a4d0abc00>,
#   < cv2.KeyPoint 0x7f8a4d0abc30>,
#   < cv2.KeyPoint 0x7f8a4d0abc60>,
#   < cv2.KeyPoint 0x7f8a4d0abc90>,
#   < cv2.KeyPoint 0x7f8a4d0abcc0>,
#   < cv2.KeyPoint 0x7f8a4d0abcf0>,
#   < cv2.KeyPoint 0x7f8a4d0abd20>,
#   < cv2.KeyPoint 0x7f8a4d0abd50>,
#   < cv2.KeyPoint 0x7f8a4d0abd80>,
#   < cv2.KeyPoint 0x7f8a4d0abdb0>,
#   < cv2.KeyPoint 0x7f8a4d0abde0>,
#   < cv2.KeyPoint 0x7f8a4d0abe10>,
#   < cv2.KeyPoint 0x7f8a4d0abe40>,
#   < cv2.KeyPoint 0x7f8a4d0abe70>,
#   < cv2.KeyPoint 0x7f8a4d0abea0>,
#   < cv2.KeyPoint 0x7f8a4d0abed0>,
#   < cv2.KeyPoint 0x7f8a4d0abf00>,
#   < cv2.KeyPoint 0x7f8a4d0abf30>,
#   < cv2.KeyPoint 0x7f8a4d0abf60>,
#   < cv2.KeyPoint 0x7f8a4d0abf90>,
#   < cv2.KeyPoint 0x7f8a4d0abfc0>,
#   < cv2.KeyPoint 0x7f8a4d08b030>,
#   < cv2.KeyPoint 0x7f8a4d08b060>,
#   < cv2.KeyPoint 0x7f8a4d08b090>,
#   < cv2.KeyPoint 0x7f8a4d08b0c0>,
#   < cv2.KeyPoint 0x7f8a4d08b0f0>,
#   < cv2.KeyPoint 0x7f8a4d08b120>,
#   < cv2.KeyPoint 0x7f8a4d08b150>,
#   < cv2.KeyPoint 0x7f8a4d08b180>,
#   < cv2.KeyPoint 0x7f8a4d08b1b0>,
#   < cv2.KeyPoint 0x7f8a4d08b1e0>,
#   < cv2.KeyPoint 0x7f8a4d08b210>,
#   < cv2.KeyPoint 0x7f8a4d08b240>,
#   < cv2.KeyPoint 0x7f8a4d08b270>,
#   < cv2.KeyPoint 0x7f8a4d08b2a0>,
#   < cv2.KeyPoint 0x7f8a4d08b2d0>,
#   < cv2.KeyPoint 0x7f8a4d08b300>,
#   < cv2.KeyPoint 0x7f8a4d08b330>,
#   < cv2.KeyPoint 0x7f8a4d08b360>,
#   < cv2.KeyPoint 0x7f8a4d08b390>,
#   < cv2.KeyPoint 0x7f8a4d08b3c0>,
#   < cv2.KeyPoint 0x7f8a4d08b3f0>,
#   < cv2.KeyPoint 0x7f8a4d08b420>,
#   < cv2.KeyPoint 0x7f8a4d08b450>,
#   < cv2.KeyPoint 0x7f8a4d08b480>,
#   < cv2.KeyPoint 0x7f8a4d08b4b0>,
#   < cv2.KeyPoint 0x7f8a4d08b4e0>,
#   < cv2.KeyPoint 0x7f8a4d08b510>,
#   < cv2.KeyPoint 0x7f8a4d08b540>,
#   < cv2.KeyPoint 0x7f8a4d08b570>,
#   < cv2.KeyPoint 0x7f8a4d08b5a0>,
#   < cv2.KeyPoint 0x7f8a4d08b5d0>,
#   < cv2.KeyPoint 0x7f8a4d08b600>,
#   < cv2.KeyPoint 0x7f8a4d08b630>,
#   < cv2.KeyPoint 0x7f8a4d08b660>,
#   < cv2.KeyPoint 0x7f8a4d08b690>,
#   < cv2.KeyPoint 0x7f8a4d08b6c0>,
#   < cv2.KeyPoint 0x7f8a4d08b6f0>,
#   < cv2.KeyPoint 0x7f8a4d08b720>,
#   < cv2.KeyPoint 0x7f8a4d08b750>,
#   < cv2.KeyPoint 0x7f8a4d08b780>,
#   < cv2.KeyPoint 0x7f8a4d08b7b0>,
#   ...),
#  array([[ 1.,  0.,  0., ..., 10.,  2.,  6.],
#         [ 0.,  0.,  0., ..., 10.,  2., 23.],
#         [ 0.,  0.,  0., ...,  8.,  2.,  7.],
#         ...,
#         [ 4., 38., 57., ...,  0.,  1.,  6.],
#         [12.,  0.,  0., ..., 45., 39., 19.],
#         [ 7.,  1.,  3., ..., 13., 29., 41.]], dtype=float32))

# %% [markdown]
# ### Part B: Matching Features

# %%
# Place Code Here
# Show an example output here

# %% [markdown]
# ### Part C: Estimating Pairwise Homographies using RANSAC

# %%
# Place Code Here
# Show an example output here

# %% [markdown]
# ### Part D: Creating the Mosaic

# %%
# Place Code Here
# Show an example output here

# %% [markdown]
# ### Final Results and Improvements

# %%
# Output results for additional images here
# Feel free to add as many cells as you wish

# %% [markdown]
# ### Grading
#
# To get 100% you need to (i) implement RANSAC and additionally (ii) either implement the feature matching yourself (instead of using built-in matching functions such as `cv2.BFMatcher()`), or incorporate one of the following improvements:
# * A nice clean compositing/blending approach so that edges/artifacts are not noticeable.
# * Automatic selection of which image should be the base
# * Handling more than 3 photos
# * Another enhancement approved by Dr. Farrell
#
# Points for this assigment will be assigned as follows (100 points total):
# * [10 pts] Extracting features from both images (interest points and descriptors).
# * [20 pts] Four-point algorithm to estimate homographies.
# * [30 pts] RANSAC implemented (partial points given for poor alignments).
# * [20 pts] Images warped appropriately (aligning on top of each other).
# * [10 pts] Clean final image (extents of merged image should fit the enscribed rectangle).
# * [10 pts] Implementing matching or other improvement (see above). Bonus points may be given for additional enhancements.
#
# ## Write-up:
# Provide an explanation for the following items:
# * In what scenarios was it difficult to get good alignments between images?
# * If you have any suggestions for how to improve this project in the future, list them here.
